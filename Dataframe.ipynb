# %%
import pandas as pd

# %%
batsman_run = pd.read_csv('Datasets/Dataframe Datasets/batsman_runs_ipl.csv')

# %%
batsman_run.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
batsman_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   batter       605 non-null    object
#  1   batsman_run  605 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 9.6+ KB

# %%
batsman_run.describe()
# Out:
#        batsman_run
# count   605.000000
# mean    464.428099
# std     985.272855
# min       0.000000
# 25%      15.000000
# 50%      73.000000
# 75%     326.000000
# max    6634.000000

# %%
diabetes = pd.read_csv("Datasets/Dataframe Datasets/diabetes.csv")

diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
movies = pd.read_csv("Datasets/Dataframe Datasets/movies.csv")
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.shape
# Out:
# (1629, 18)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl_matches = pd.read_csv("Datasets/Dataframe Datasets/ipl-matches.csv")

ipl_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# #### In IPL Dataset:

# %%
# Find all the final winners

# %%
ipl_matches.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_matches[ipl_matches['MatchNumber'] == 'Final'][['Season','WinningTeam']].reset_index(drop=True)
# Out:
#      Season            WinningTeam
# 0      2022         Gujarat Titans
# 1      2021    Chennai Super Kings
# 2   2020/21         Mumbai Indians
# 3      2019         Mumbai Indians
# 4      2018    Chennai Super Kings
# 5      2017         Mumbai Indians
# 6      2016    Sunrisers Hyderabad
# 7      2015         Mumbai Indians
# 8      2014  Kolkata Knight Riders
# 9      2013         Mumbai Indians
# 10     2012  Kolkata Knight Riders
# 11     2011    Chennai Super Kings
# 12  2009/10    Chennai Super Kings
# 13     2009        Deccan Chargers
# 14  2007/08       Rajasthan Royals

# %%
# How many SuperOver Finishes have occured.

ipl_matches['SuperOver'].value_counts().values[1]
# Out:
# np.int64(14)

# %%
# No. of matches CSK Won in Kolkata.

ipl_matches[(ipl_matches['City'] == 'Kolkata') & (ipl_matches['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
ipl_matches[(ipl_matches['City'] == 'Kolkata') & (ipl_matches['WinningTeam'] == 'Chennai Super Kings')]['ID'].count()
# Out:
# np.int64(5)

# %%
ipl_matches[['City', 'WinningTeam' ]]
# Out:
#            City                  WinningTeam
# 0     Ahmedabad               Gujarat Titans
# 1     Ahmedabad             Rajasthan Royals
# 2       Kolkata  Royal Challengers Bangalore
# 3       Kolkata               Gujarat Titans
# 4        Mumbai                 Punjab Kings
# ..          ...                          ...
# 945     Kolkata        Kolkata Knight Riders
# 946      Mumbai  Royal Challengers Bangalore
# 947       Delhi             Delhi Daredevils
# 948  Chandigarh          Chennai Super Kings
# 949   Bangalore        Kolkata Knight Riders
#
# [950 rows x 2 columns]

# %%
# Find if: toss winner is match winner (in %)

toss_winner_is_match_winner_number = ipl_matches[ipl_matches['TossWinner'] == ipl_matches['WinningTeam']].shape[0]
total_game = ipl_matches.shape[0]

(toss_winner_is_match_winner_number/total_game) * 100
# Out:
# 51.473684210526315

# %% [markdown]
# ### Movies Datasets

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# movies with rating higher than 8 and votes>10000

movies[(movies['imdb_rating'] > 8.0) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7

movies['is_action'] = movies['genres'].str.split('|').apply(lambda x: 'Action' in x)

# %%
movies['genres'].str.split('|').apply(lambda x: 'Action' in x)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627     True
# 1628    False
# Name: genres, Length: 1629, dtype: bool

# %%
movies[movies['is_action'] & (movies['imdb_rating'] > 7.0)].shape[0]
# Out:
# 75

# %%
movies['genres'].str.contains('Action')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627     True
# 1628    False
# Name: genres, Length: 1629, dtype: bool

# %% [markdown]
# ### IPL Matches

# %%
# write a function that can return the track record of 2 teams against each other

temp_df = ipl_matches[['Team1', 'Team2', 'WinningTeam']]
temp_df
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
new_df = pd.DataFrame(temp_df.groupby(['Team1','Team2'])['WinningTeam'].value_counts())
new_df.reset_index(level=[2],inplace=True)
new_df
# Out:
#                                                                  WinningTeam  \
# Team1               Team2
# Chennai Super Kings Deccan Chargers                      Chennai Super Kings
#                     Deccan Chargers                          Deccan Chargers
#                     Delhi Capitals                            Delhi Capitals
#                     Delhi Capitals                       Chennai Super Kings
#                     Delhi Daredevils                     Chennai Super Kings
# ...                                                                      ...
# Sunrisers Hyderabad Rajasthan Royals                     Sunrisers Hyderabad
#                     Rising Pune Supergiant            Rising Pune Supergiant
#                     Rising Pune Supergiants          Rising Pune Supergiants
#                     Royal Challengers Bangalore          Sunrisers Hyderabad
#                     Royal Challengers Bangalore  Royal Challengers Bangalore
#
# ...

# %%
new_df.loc[("Chennai Super Kings","Delhi Daredevils")]
# Out:
#                                               WinningTeam  count
# Team1               Team2
# Chennai Super Kings Delhi Daredevils  Chennai Super Kings      7
#                     Delhi Daredevils     Delhi Daredevils      3
